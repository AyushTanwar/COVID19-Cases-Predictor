# %%
import seaborn as sb
import pandas as pd
import numpy as np
import sklearn
import matplotlib

# %%
hdf = pd.read_csv('HospitalBedsIndia.csv')

# %%
hdf
# Out:
#     Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0     1  Andaman & Nicobar Islands                           27
# 1     2             Andhra Pradesh                         1417
# 2     3          Arunachal Pradesh                          122
# 3     4                      Assam                         1007
# 4     5                      Bihar                         2007
# 5     6                 Chandigarh                           40
# 6     7               Chhattisgarh                          813
# 7     8       Dadra & Nagar Haveli                            9
# 8     9                Daman & Diu                            4
# 9    10                      Delhi                          534
# 10   11                        Goa                           31
# 11   12                    Gujarat                         1770
# 12   13                    Haryana                          500
# 13   14           Himachal Pradesh                          516
# ...

# %%
total_beds =[0]*len(hdf)
for i in range(0,len(hdf)):
    total_beds[i] = hdf.loc[i,'NumPublicBeds_HMIS'] + hdf.loc[i,'NumRuralBeds_NHP18'] + hdf.loc[i,'NumUrbanBeds_NHP18']
    #+ NumRuralBeds_NHP18[i] + NumUrbanBeds_NHP18[i]

# %%
len(hdf)
# Out:
# 37

# %%
total_beds
# Out:
# [2321,
#  83937,
#  4724,
#  36257,
#  29815,
#  4534,
#  23766,
#  1157,
#  538,
#  44955,
#  5679,
#  73409,
#  25081,
#  21105,
#  22993,
#  18188,
#  126498,
#  77515,
#  550,
#  66979,
#  120444,
#  3989,
#  9042,
#  4309,
#  3824,
#  35016,
#  8031,
#  31460,
#  83692,
#  2705,
#  150148,
#  38341,
#  9312,
#  134570,
#  15172,
#  129729,
#  1449785]

# %%
per_day_cases = pd.read_csv('StatewiseTestingDetails.csv')

# %%
per_day_cases
# Out:
#             Date                        State  TotalSamples Negative  Positive
# 0     2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1     2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2     2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3     2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4     2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
# 5     2020-05-19  Andaman and Nicobar Islands        6965.0      NaN      33.0
# 6     2020-05-20  Andaman and Nicobar Islands        7082.0      NaN      33.0
# 7     2020-05-21  Andaman and Nicobar Islands        7167.0      NaN      33.0
# 8     2020-05-22  Andaman and Nicobar Islands        7263.0      NaN      33.0
# 9     2020-05-23  Andaman and Nicobar Islands        7327.0      NaN      33.0
# 10    2020-05-24  Andaman and Nicobar Islands        7327.0      NaN      33.0
# ...

# %%
#sdf = []
#df.loc[df['column_name'] == some_value] pd.DataFrame(boxes, columns= ['Color','Shape','Price'])
#state = input()
state = 'Delhi'
#sdf =     pd.DataFrame(per_day_cases,rows = ['West Bengal'])
sdf = per_day_cases.loc[per_day_cases['State'] == state]

# %%
bed_numb = 0;
for i in range (0,len(hdf)):
    if(state == hdf.iloc[i]['State/UT']):
        print(hdf.iloc[i]['State/UT'])
        bed_ind = i
bed_numb = total_beds[bed_ind]
print(bed_numb)
# Out:
# Delhi
# 44955

# %%
sdf
# Out:
#             Date  State  TotalSamples Negative  Positive
# 1028  2020-04-01  Delhi        2621.0      NaN       NaN
# 1029  2020-04-07  Delhi        9041.0     7308     576.0
# 1030  2020-04-09  Delhi        9968.0     8643     720.0
# 1031  2020-04-10  Delhi       11061.0     9662     903.0
# 1032  2020-04-11  Delhi       11709.0    10218    1069.0
# 1033  2020-04-12  Delhi       14036.0    11748    1154.0
# 1034  2020-04-13  Delhi       15032.0    12283    1510.0
# 1035  2020-04-14  Delhi       16282.0    13748    1561.0
# 1036  2020-04-15  Delhi       16605.0    13865    1578.0
# 1037  2020-04-16  Delhi       18784.0    14692    1640.0
# 1038  2020-04-17  Delhi       21409.0    16899    1707.0
# 1039  2020-04-18  Delhi       22283.0    17449    1893.0
# 1040  2020-04-19  Delhi       24387.0    19393    2003.0
# 1041  2020-04-20  Delhi       25900.0    20712    2081.0
# 1042  2020-04-21  Delhi       26627.0    21810    2156.0
# ...

# %%
#sdf.replace(to_replace ="NaN", value =0) 
sdf = sdf.replace(to_replace = np.nan, value =0)

# %%
#sdf['Positive'] = pd.to_numeric(sdf['Positive'])
sdf['TotalSamples'] = sdf['TotalSamples'].astype(int)
sdf['TotalSamples'] = sdf['TotalSamples'].astype(int)

# %%
temp = sdf.iloc[1]['Positive']
templ = [0]*len(sdf)
print(sdf.iloc[1]['TotalSamples'])
for i in range (1,len(sdf)):
    if(sdf.iloc[i]['Positive']==0):
        templ[i] = int(temp)   
    else:
        templ[i] = int(sdf.iloc[i]['Positive'])
        temp = int(sdf.iloc[i]['Positive'])
sdf['Positive'] = templ
print(sdf)
# Out:
# 9041
#             Date  State  TotalSamples Negative  Positive
# 1028  2020-04-01  Delhi          2621        0         0
# 1029  2020-04-07  Delhi          9041     7308       576
# 1030  2020-04-09  Delhi          9968     8643       720
# 1031  2020-04-10  Delhi         11061     9662       903
# 1032  2020-04-11  Delhi         11709    10218      1069
# 1033  2020-04-12  Delhi         14036    11748      1154
# 1034  2020-04-13  Delhi         15032    12283      1510
# 1035  2020-04-14  Delhi         16282    13748      1561
# 1036  2020-04-15  Delhi         16605    13865      1578
# 1037  2020-04-16  Delhi         18784    14692      1640
# 1038  2020-04-17  Delhi         21409    16899      1707
# 1039  2020-04-18  Delhi         22283    17449      1893
# 1040  2020-04-19  Delhi         24387    19393      2003
# 1041  2020-04-20  Delhi         25900    20712      2081
# 1042  2020-04-21  Delhi         26627    21810      2156
# ...

# %%
sdf = sdf.iloc[1:,]
print(sdf)
print(len(sdf))
# Out:
#             Date  State  TotalSamples Negative  Positive
# 1029  2020-04-07  Delhi          9041     7308       576
# 1030  2020-04-09  Delhi          9968     8643       720
# 1031  2020-04-10  Delhi         11061     9662       903
# 1032  2020-04-11  Delhi         11709    10218      1069
# 1033  2020-04-12  Delhi         14036    11748      1154
# 1034  2020-04-13  Delhi         15032    12283      1510
# 1035  2020-04-14  Delhi         16282    13748      1561
# 1036  2020-04-15  Delhi         16605    13865      1578
# 1037  2020-04-16  Delhi         18784    14692      1640
# 1038  2020-04-17  Delhi         21409    16899      1707
# 1039  2020-04-18  Delhi         22283    17449      1893
# 1040  2020-04-19  Delhi         24387    19393      2003
# 1041  2020-04-20  Delhi         25900    20712      2081
# 1042  2020-04-21  Delhi         26627    21810      2156
# 1043  2020-04-22  Delhi         28309    22713      2248
# ...

# %%
perday_inc = [0] * len(sdf)
temp = sdf.iloc[2]['Positive'] - sdf.iloc[1]['Positive']
for i in range (1,len(sdf)):
    if(int(sdf.iloc[i]['Positive'] - sdf.iloc[i-1]['Positive'])==0):
        perday_inc[i] = int(temp) +30  
        temp = int(temp) +30  
    else:
        perday_inc[i] = int(sdf.iloc[i]['Positive'] - sdf.iloc[i-1]['Positive'])
        temp = perday_inc[i]
#df2 = df.assign(address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']) 
sdf["perday_inc"] = perday_inc
print(perday_inc)
# Out:
# [0, 144, 183, 166, 85, 356, 51, 17, 62, 67, 186, 110, 78, 75, 92, 127, 139, 111, 293, 190, 206, 125, 683, 427, 349, 206, 428, 448, 338, 224, 381, 310, 406, 359, 472, 425, 438, 422, 299, 500, 534, 571, 660, 591, 508, 635, 412, 792, 1024, 1105, 1163, 1295, 990, 1298, 1513, 1359, 1330, 1320, 1282, 1007, 1366, 1501, 1877, 2137, 2134, 2224, 1647, 1859, 2414, 2877, 3137, 3630, 3000, 2909, 3947, 3788, 3390, 3460, 2948, 2889, 2084, 2199, 2442, 2373, 2520, 2505, 2244, 1379, 2008, 2033, 2187, 2089, 1781, 1573, 1246, 1606, 1647, 1652, 1462, 1475, 1211, 954, 1349, 1227, 1041, 1025, 1142, 1075, 613, 1056, 1035, 1093, 1123, 2313, 961, 805, 674, 1076, 1299, 1192, 1404, 1300, 707, 737, 767, 797, 827, 5794, 5824, 5854, 5884, 5914, 5944, 5974, 6004, 6034, 6064, 6094, 6124, 6154]

# %%
print(sdf)
# Out:
#             Date  State  TotalSamples Negative  Positive  perday_inc
# 1029  2020-04-07  Delhi          9041     7308       576           0
# 1030  2020-04-09  Delhi          9968     8643       720         144
# 1031  2020-04-10  Delhi         11061     9662       903         183
# 1032  2020-04-11  Delhi         11709    10218      1069         166
# 1033  2020-04-12  Delhi         14036    11748      1154          85
# 1034  2020-04-13  Delhi         15032    12283      1510         356
# 1035  2020-04-14  Delhi         16282    13748      1561          51
# 1036  2020-04-15  Delhi         16605    13865      1578          17
# 1037  2020-04-16  Delhi         18784    14692      1640          62
# 1038  2020-04-17  Delhi         21409    16899      1707          67
# 1039  2020-04-18  Delhi         22283    17449      1893         186
# 1040  2020-04-19  Delhi         24387    19393      2003         110
# 1041  2020-04-20  Delhi         25900    20712      2081          78
# ...

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

df = DataFrame(sdf,columns=['Date','perday_inc','TotalSamples'])
df.plot(x ='Date', y='perday_inc',label = "per day cases")
df.plot(x ='Date', y='TotalSamples', label = "Total tests",color = 'orange')


#State/UT
plt.show()

# %%
X = sdf.iloc[:, 2:3].values
Y = sdf.iloc[:, 4:5].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'orange')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('No of Tests vs Positive (Training set)')
plt.xlabel('No of Tests')
plt.ylabel('Positive')
plt.show()

# Visualising the Test set results
plt.scatter(X_test, y_test, color = 'orange')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('No of Tests vs Positive (Test set)')
plt.xlabel('No of Tests')
plt.ylabel('Positive')
plt.show()

# %%
# Support Vector Regression

Xs = sdf.iloc[:, 2:3].values
ys = sdf.iloc[:, 4:5].values

# %%
from sklearn.preprocessing import StandardScaler
sc_Xs = StandardScaler()
sc_ys = StandardScaler()
Xs = sc_Xs.fit_transform(Xs)
ys = sc_ys.fit_transform(ys)

# Fitting SVR to the dataset
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf',C=100, gamma=0.1, epsilon=.1)
regressor.fit(Xs, ys)
# Out:
# /Users/ayushtw/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/ayushtw/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/ayushtw/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=100, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#   kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting a new result
#svr.fit(X, y).predict(X)
y_preds = regressor.predict(Xs)
y_preds = sc_ys.inverse_transform(y_preds)

# %%
# Visualising the SVR results
plt.scatter(Xs, ys, color = 'orange')
plt.plot(Xs, regressor.predict(Xs), color = 'blue')
plt.title('Number of tests vs Positive (SVR)')
plt.xlabel('Number of tests')
plt.ylabel('Positive')
plt.show()
